# %%
# !nsys --version
# Out:
# NVIDIA Nsight Systems version 2022.4.2.1-df9881f

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv1_minimax_basic --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv1_minimax_basic.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)        Name
#  --------  ---------------  ---------  --------  --------  --------  --------  -----------  ----------------
#      71.9         25547579         33  774169.1  386654.0     75461   3970926     999553.9  cuMemcpyDtoH_v2
#      10.6          3758453         66   56946.3   14577.5      7364   2334131     286494.3  cuMemAlloc_v2
#       6.9          2449303         33   74221.3   72475.0     39003    129522      20268.9  cuMemcpyHtoD_v2
#       6.1          2185531         33   66228.2   53580.0     39704    183593      33815.1  cuLaunchKernel
#       4.5          1596133         66   24183.8    2399.5      1813    448160      83828.3  cuMemFree_v2
#       0.0             4218          1    4218.0    4218.0      4218      4218          0.0  cuCtxSynchronize
#
#
#  ** CUDA GPU Kernel Summary (gpukernsum):
#
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv1_minimax_alphabeta --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv1_minimax_alphabeta.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)        Name
#  --------  ---------------  ---------  --------  --------  --------  --------  -----------  ----------------
#      70.7         20220604         33  612745.6  427180.0     30868   3425675     805051.7  cuMemcpyDtoH_v2
#      11.7          3338218         66   50579.1    2625.0      1824   2214618     280176.1  cuMemFree_v2
#       7.3          2089552         33   63319.8   52639.0     33453    136706      26740.7  cuMemcpyHtoD_v2
#       5.7          1616756         33   48992.6   47028.0     28734     87744      15516.1  cuLaunchKernel
#       4.7          1336721         66   20253.3    9127.0      5090    200756      37836.3  cuMemAlloc_v2
#       0.0             3747          1    3747.0    3747.0      3747      3747          0.0  cuCtxSynchronize
#
#
#  ** CUDA GPU Kernel Summary (gpukernsum):
#
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv1_minimax_alphabeta_movesorting --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv1_minimax_alphabeta_movesorting.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
# Capture range started in the application
# ...
# Capture range ended in the application
# Processing events...
# Saving temporary "C:\Users\Asus\AppData\Local\Temp\nsys-report-64c0-c783-c3ca-e4f3.qdstrm" file to disk...
#
# Creating final output files...
#
# Processing [0%                                                                 ]
# Processing [=====12%                                                           ]
# Processing [=============25%                                                   ]
# Processing [0%                                                                 ]
# Processing [=============================49%                                   ]
# Processing [==============================================================98%  ]
# Processing [=============================================================96%   ]
# Processing [===========================================================94%     ]
# Processing [=======================================================88%         ]
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv2_minimax_basic --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv2_minimax_basic.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)   Med (ns)  Min (ns)  Max (ns)  StdDev (ns)        Name
#  --------  ---------------  ---------  ---------  --------  --------  --------  -----------  ----------------
#      69.6          9148763          4  2287190.8  506313.5     41047   8095089    3892274.8  cuMemcpyDtoH_v2
#      19.5          2564235         22   116556.1    3516.5      2144   2466710     524928.6  cuMemFree_v2
#       8.9          1170501         10   117050.1   42088.5     27542    448510     150524.1  cuMemcpyHtoD_v2
#       1.1           149200          2    74600.0   74600.0     74310     74890        410.1  cuLaunchKernel
#       0.8           111299         12     9274.9    7604.5      5170     25658       5543.6  cuMemAlloc_v2
#       0.0             5610          1     5610.0    5610.0      5610      5610          0.0  cuCtxSynchronize
#
#
#  ** CUDA GPU Kernel Summary (gpukernsum):
#
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv2_minimax_alphabeta --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv2_minimax_alphabeta.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
# Capture range started in the application
# ...
# Capture range ended in the application
# Processing events...
# Saving temporary "C:\Users\Asus\AppData\Local\Temp\nsys-report-ec84-651a-405a-2947.qdstrm" file to disk...
#
# Creating final output files...
#
# Processing [0%                                                                 ]
# Processing [=====12%                                                           ]
# Processing [=============25%                                                   ]
# Processing [0%                                                                 ]
# Processing [=======================40%                                         ]
# Processing [==================================================80%              ]
# Processing [=================================================79%               ]
# Processing [=================================================78%               ]
# Processing [================================================77%                ]
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv2_minimax_alphabeta_movesorting --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv2_minimax_alphabeta_movesorting.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)   Med (ns)  Min (ns)  Max (ns)  StdDev (ns)        Name
#  --------  ---------------  ---------  ---------  --------  --------  --------  -----------  ----------------
#      68.0          8015862          4  2003965.5   68343.5     28273   7850902    3898049.1  cuMemcpyDtoH_v2
#      19.4          2289776         22   104080.7    2660.0      1953   2210860     470565.8  cuMemFree_v2
#      10.2          1197854         10   119785.4   46873.0     27441    457296     152308.2  cuMemcpyHtoD_v2
#       1.4           165059          2    82529.5   82529.5     71514     93545      15578.3  cuLaunchKernel
#       0.9           104805         12     8733.8    6026.5      4258     24255       5733.3  cuMemAlloc_v2
#       0.1             8786          1     8786.0    8786.0      8786      8786          0.0  cuCtxSynchronize
#
#
#  ** CUDA GPU Kernel Summary (gpukernsum):
#
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv3_minimax_basic --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv3_minimax_basic.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)        Name
#  --------  ---------------  ---------  --------  --------  --------  --------  -----------  ----------------
#      41.3          2351364          4  587841.0  512405.0     28142   1298412     645788.5  cuMemcpyDtoH_v2
#      39.3          2240724         22  101851.1    3191.0      2044   2139736     455200.4  cuMemFree_v2
#      14.7           837979         10   83797.9   29785.5     26550    457006     133884.4  cuMemcpyHtoD_v2
#       2.4           134501          2   67250.5   67250.5     61585     72916       8012.2  cuLaunchKernel
#       2.2           123674         12   10306.2    7183.5      3978     31599       8086.6  cuMemAlloc_v2
#       0.1             6322          1    6322.0    6322.0      6322      6322          0.0  cuCtxSynchronize
#
#
#  ** CUDA GPU Kernel Summary (gpukernsum):
#
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv3_minimax_alphabeta --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv3_minimax_alphabeta.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)   Med (ns)  Min (ns)  Max (ns)  StdDev (ns)        Name
#  --------  ---------------  ---------  ---------  --------  --------  --------  -----------  ----------------
#      84.6          8923971          5  1784794.2   68308.0     24175   7796570    3386530.9  cuMemcpyDtoH_v2
#      11.3          1189923         16    74370.2   28823.5     25898    491415     122640.5  cuMemcpyHtoD_v2
#       1.6           170941          2    85470.5   85470.5     61706    109235      33608.1  cuLaunchKernel
#       1.5           163276         16    10204.8    5961.5      4639     35095       8654.2  cuMemAlloc_v2
#       0.9            91943         22     4179.2    2855.0      2084     19467       4259.7  cuMemFree_v2
#       0.0             2354          1     2354.0    2354.0      2354      2354          0.0  cuCtxSynchronize
#
#
#  ** CUDA GPU Kernel Summary (gpukernsum):
#
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv3_minimax_alphabeta_movesorting --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv3_minimax_alphabeta_movesorting.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)        Name
#  --------  ---------------  ---------  --------  --------  --------  --------  -----------  ----------------
#      51.4          2583548          4  645887.0  537446.5     22502   1486153     739309.4  cuMemcpyDtoH_v2
#      39.8          2000839         16  125052.4   47669.0     13736    999832     243533.2  cuMemcpyHtoD_v2
#       4.5           224268         16   14016.8   14211.5      4628     30157       8238.1  cuMemAlloc_v2
#       2.9           146043          2   73021.5   73021.5     66134     79909       9740.4  cuLaunchKernel
#       1.5            73679         22    3349.0    2630.0      1993     11542       2418.3  cuMemFree_v2
#       0.0             2054          1    2054.0    2054.0      2054      2054          0.0  cuCtxSynchronize
#
#
#  ** CUDA GPU Kernel Summary (gpukernsum):
#
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv4_minimax_basic --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv4_minimax_basic.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)          Name
#  --------  ---------------  ---------  --------  --------  --------  --------  -----------  --------------------
#      31.0          8714658        275   31689.7   28222.0     12263    107421      13728.7  cuMemcpyHtoDAsync_v2
#      19.6          5523684        330   16738.4    2660.0      1713   4141275     227939.8  cuMemFree_v2
#      18.6          5233532         55   95155.1   62086.0     38783    789825     129737.3  cuLaunchKernel
#      10.8          3049941        110   27726.7   26339.0     20267    127770      10026.5  cuMemcpyDtoHAsync_v2
#       9.8          2749106        330    8330.6    6247.0      3597    116929       7559.6  cuMemAlloc_v2
#       8.8          2466955         55   44853.7    5600.0      3226   2047945     275182.4  cuStreamCreate
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv4_minimax_alphabeta --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv4_minimax_alphabeta.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)          Name
#  --------  ---------------  ---------  --------  --------  --------  --------  -----------  --------------------
#      29.7          8674742        275   31544.5   27712.0     12353    132939      18291.7  cuMemcpyHtoDAsync_v2
#      19.0          5540481        330   16789.3    2776.0      1563   1276110      92089.5  cuMemFree_v2
#      15.3          4453110         55   80965.6   62377.0     30277    694065      88587.3  cuLaunchKernel
#      13.2          3856275         55   70114.1    5741.0      3396   3265849     439276.5  cuStreamCreate
#      10.9          3191704        110   29015.5   26605.0     19516    106169      10450.5  cuMemcpyDtoHAsync_v2
#      10.4          3036903        330    9202.7    6522.0      3677    107782       9044.6  cuMemAlloc_v2
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv4_minimax_alphabeta_movesorting --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv4_minimax_alphabeta_movesorting.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)          Name
#  --------  ---------------  ---------  --------  --------  --------  --------  -----------  --------------------
#      30.7          7796553        275   28351.1   27552.0     12153    136495      13582.6  cuMemcpyHtoDAsync_v2
#      22.3          5672227        330   17188.6    2685.0      1593   2760439     157718.2  cuMemFree_v2
#      15.1          3837819         55   69778.5   59551.0     31339    377507      47830.1  cuLaunchKernel
#      11.6          2956397        110   26876.3   26044.0     21030    118242       8998.3  cuMemcpyDtoHAsync_v2
#      10.4          2635118        330    7985.2    6382.0      3937     50214       4832.3  cuMemAlloc_v2
#       8.5          2173229         55   39513.3    5430.0      3487   1803026     242233.4  cuStreamCreate
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv5_minimax_basic --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv5_minimax_basic.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)   Med (ns)   Min (ns)  Max (ns)  StdDev (ns)          Name
#  --------  ---------------  ---------  ---------  ---------  --------  --------  -----------  --------------------
#      81.4          9808397          1  9808397.0  9808397.0   9808397   9808397          0.0  cuStreamSynchronize
#       7.3           875291          6   145881.8    82530.0     59131    382116     127528.0  cuMemcpyHtoD_v2
#       4.5           548007          7    78286.7    49573.0     17052    203711      63061.1  cuMemcpyHtoDAsync_v2
#       2.6           318989         13    24537.6    16842.0      7203     59822      17791.3  cuMemAlloc_v2
#       1.7           202389          3    67463.0    36799.0     29836    135754      59244.1  cuMemcpyDtoH_v2
#       1.4           170188          1   170188.0   170188.0    170188    170188          0.0  cuLaunchKernel
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv5_minimax_alphabeta --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv5_minimax_alphabeta.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
# Capture range started in the application
# ...
# Capture range ended in the application
# Processing events...
# Saving temporary "C:\Users\Asus\AppData\Local\Temp\nsys-report-f45f-3117-45f8-c13a.qdstrm" file to disk...
#
# Creating final output files...
#
# Processing [0%                                                                 ]
# Processing [=====12%                                                           ]
# Processing [=============25%                                                   ]
# Processing [0%                                                                 ]
# Processing [=============================49%                                   ]
# Processing [==============================================================98%  ]
# Processing [=============================================================97%   ]
# Processing [============================================================95%    ]
# Processing [===========================================================94%     ]
# ...

# %%
# !nsys profile --stats=true --show-output=true --trace=cuda --output=parallelv5_minimax_alphabeta_movesorting --force-overwrite=true --capture-range=cudaProfilerApi "C:\Users\Asus\AppData\Local\Programs\Python\Python310\python.exe" parallelv5_minimax_alphabeta_movesorting.py --fen="r3k2r/p1ppqpbp/Bn2pnp1/3PN3/1p2P3/2N2Q1p/PPPB1PPP/R3K2R b KQkq - 0 1" --search_depth=2
# Out:
#  ** CUDA API Summary (cudaapisum):
#
#  Time (%)  Total Time (ns)  Num Calls  Avg (ns)   Med (ns)   Min (ns)  Max (ns)  StdDev (ns)          Name
#  --------  ---------------  ---------  ---------  ---------  --------  --------  -----------  --------------------
#      85.9          9780435          1  9780435.0  9780435.0   9780435   9780435          0.0  cuStreamSynchronize
#       7.8           892391          6   148731.8    85219.5     41247    475240     164301.1  cuMemcpyHtoD_v2
#       1.7           189685          3    63228.3    34164.0     27301    128220      56388.9  cuMemcpyDtoH_v2
#       1.7           189184          7    27026.3    28874.0     13064     36137       7197.1  cuMemcpyHtoDAsync_v2
#       1.4           154747         13    11903.6    12203.0      4739     26960       7144.0  cuMemAlloc_v2
#       0.8            86753         22     3943.3     2810.5      2054     22231       4214.6  cuMemFree_v2
# ...
